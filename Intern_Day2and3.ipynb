# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/Internship_NITP/blob/main/Intern_Day2and3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
normal=pd.read_csv('/content/SDNFlow_Dataset_Normal.csv')

# %%
attack=pd.read_csv('/content/SDNFlow_Dataset_attack.csv')

# %%
d=pd.concat([normal,attack],axis=0)

# %%
d
# Out:
#        flow_ID  eth_type        ipv4_src        ipv4_dst  ip_proto  src_port  \
# 0            1      2048  192.168.56.201    192.168.56.1       6.0      22.0
# 1            2      2048    192.168.56.1  192.168.56.201       6.0   41410.0
# 2            3      2048  192.168.56.203  192.168.56.201       1.0       0.0
# 3            4      2048  192.168.56.201  192.168.56.203      17.0   57426.0
# 4            5      2048  192.168.56.201  192.168.56.203      17.0   48549.0
# ...        ...       ...             ...             ...       ...       ...
# 43602    43603      2048   23.19.211.137     10.10.10.16       6.0    2935.0
# 43603    43604      2048    34.186.92.15     10.10.10.16       6.0    2940.0
# 43604    43605      2048  61.109.254.142     10.10.10.16       6.0    2948.0
# 43605    43606      2048     15.92.67.78     10.10.10.16       6.0    2952.0
# 43606    43607      2048  212.143.254.95     10.10.10.16       6.0    2956.0
#
# ...

# %%
d['Attack'].value_counts()
# Out:
# Attack
# 1.0    43606
# 0.0    37247
# Name: count, dtype: int64

# %%
d
# Out:
#        flow_ID  eth_type        ipv4_src        ipv4_dst  ip_proto  src_port  \
# 0            1      2048  192.168.56.201    192.168.56.1       6.0      22.0
# 1            2      2048    192.168.56.1  192.168.56.201       6.0   41410.0
# 2            3      2048  192.168.56.203  192.168.56.201       1.0       0.0
# 3            4      2048  192.168.56.201  192.168.56.203      17.0   57426.0
# 4            5      2048  192.168.56.201  192.168.56.203      17.0   48549.0
# ...        ...       ...             ...             ...       ...       ...
# 43602    43603      2048   23.19.211.137     10.10.10.16       6.0    2935.0
# 43603    43604      2048    34.186.92.15     10.10.10.16       6.0    2940.0
# 43604    43605      2048  61.109.254.142     10.10.10.16       6.0    2948.0
# 43605    43606      2048     15.92.67.78     10.10.10.16       6.0    2952.0
# 43606    43607      2048  212.143.254.95     10.10.10.16       6.0    2956.0
#
# ...

# %%
d = d.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
d
# Out:
#        flow_ID  eth_type        ipv4_src         ipv4_dst  ip_proto  src_port  \
# 0        14188      2048      8.43.72.98   192.168.56.203       6.0     443.0
# 1        29086      2048  192.168.56.203     95.101.29.75       6.0   43496.0
# 2        28055      2048      10.10.10.4   195.207.16.142       6.0    5432.0
# 3        43515      2048     10.10.10.16  159.241.250.220       6.0      88.0
# 4         8701      2048  192.168.56.203    52.95.126.138       6.0   38224.0
# ...        ...       ...             ...              ...       ...       ...
# 80850     6266      2048  192.168.56.203    18.155.248.84       6.0   35006.0
# 80851    17639      2048      10.10.10.4   119.196.238.92       6.0      23.0
# 80852    39573      2048     10.10.10.12    88.252.254.23       6.0     464.0
# 80853      861      2048  216.239.34.178   192.168.56.203       6.0     443.0
# 80854    15796      2048    157.240.6.23   192.168.56.203       6.0     443.0
#
# ...

# %%
d.isnull().sum()
# Out:
# flow_ID                  0
# eth_type                 0
# ipv4_src                 1
# ipv4_dst                 1
# ip_proto                 1
# src_port                 1
# dst_port                 1
# flow_duration            1
# tot_len_pkts             1
# tot_pkts                 1
# flow_byts_s              1
# flow_pkts_s              1
# pkt_size_average         1
# fwd_header_len           1
# Byts_max_interval_2s     1
# Byts_min_interval_2s     1
# Byts_mean_interval_2s    1
# Byts_std_interval_2s     1
# Pkts_max_interval_2s     1
# Pkts_mean_interval_2s    1
# Pkts_min_interval_2s     1
# Pkts_std_interval_2s     2
# active_max               2
# active_mean              2
# active_min               2
# active_std               2
# idle_max                 2
# idle_mean                2
# idle_min                 2
# idle_std                 2
# TnBPDstIP                2
# TnBPSrcIP                2
# TnPPDstIP                2
# TnPPSrcIP                2
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()

# %%
attacktypes=labelencoder.fit_transform(d.Category)

# %%
d.head()
# Out:
#    flow_ID  eth_type        ipv4_src         ipv4_dst  ip_proto  src_port  \
# 0    14188      2048      8.43.72.98   192.168.56.203       6.0     443.0
# 1    29086      2048  192.168.56.203     95.101.29.75       6.0   43496.0
# 2    28055      2048      10.10.10.4   195.207.16.142       6.0    5432.0
# 3    43515      2048     10.10.10.16  159.241.250.220       6.0      88.0
# 4     8701      2048  192.168.56.203    52.95.126.138       6.0   38224.0
#
#    dst_port  flow_duration  tot_len_pkts  tot_pkts  ...  idle_std  \
# 0   37004.0          0.385           0.0       0.0  ...       0.0
# 1      80.0          6.747         547.0       2.0  ...       0.0
# 2    1537.0          0.443           0.0       0.0  ...       0.0
# 3    3030.0          0.183           0.0       0.0  ...       0.0
# 4     443.0          0.338           0.0       0.0  ...       0.0
#
#      TnBPDstIP  TnBPSrcIP  TnPPDstIP  TnPPSrcIP  TnPPerDport  Tn_FlowsPDstIP  \
# ...

# %%
d['Category']=labelencoder.fit_transform(d['Category'])

# %%
d.head()
# Out:
#    flow_ID  eth_type        ipv4_src         ipv4_dst  ip_proto  src_port  \
# 0    14188      2048      8.43.72.98   192.168.56.203       6.0     443.0
# 1    29086      2048  192.168.56.203     95.101.29.75       6.0   43496.0
# 2    28055      2048      10.10.10.4   195.207.16.142       6.0    5432.0
# 3    43515      2048     10.10.10.16  159.241.250.220       6.0      88.0
# 4     8701      2048  192.168.56.203    52.95.126.138       6.0   38224.0
#
#    dst_port  flow_duration  tot_len_pkts  tot_pkts  ...  idle_std  \
# 0   37004.0          0.385           0.0       0.0  ...       0.0
# 1      80.0          6.747         547.0       2.0  ...       0.0
# 2    1537.0          0.443           0.0       0.0  ...       0.0
# 3    3030.0          0.183           0.0       0.0  ...       0.0
# 4     443.0          0.338           0.0       0.0  ...       0.0
#
#      TnBPDstIP  TnBPSrcIP  TnPPDstIP  TnPPSrcIP  TnPPerDport  Tn_FlowsPDstIP  \
# ...

# %%
d.drop(columns=['ipv4_src','ipv4_dst'],inplace=True)

# %%
d.head()
# Out:
#    flow_ID  eth_type  ip_proto  src_port  dst_port  flow_duration  \
# 0    14188      2048       6.0     443.0   37004.0          0.385
# 1    29086      2048       6.0   43496.0      80.0          6.747
# 2    28055      2048       6.0    5432.0    1537.0          0.443
# 3    43515      2048       6.0      88.0    3030.0          0.183
# 4     8701      2048       6.0   38224.0     443.0          0.338
#
#    tot_len_pkts  tot_pkts  flow_byts_s  flow_pkts_s  ...  idle_std  \
# 0           0.0       0.0      0.00000     0.000000  ...       0.0
# 1         547.0       2.0     81.07307     0.296428  ...       0.0
# 2           0.0       0.0      0.00000     0.000000  ...       0.0
# 3           0.0       0.0      0.00000     0.000000  ...       0.0
# 4           0.0       0.0      0.00000     0.000000  ...       0.0
#
#      TnBPDstIP  TnBPSrcIP  TnPPDstIP  TnPPSrcIP  TnPPerDport  Tn_FlowsPDstIP  \
# 0  110354785.0      726.0    93144.0       11.0          0.0           179.0
# ...

# %%
d.isnull().sum()
# Out:
# flow_ID                  0
# eth_type                 0
# ip_proto                 1
# src_port                 1
# dst_port                 1
# flow_duration            1
# tot_len_pkts             1
# tot_pkts                 1
# flow_byts_s              1
# flow_pkts_s              1
# pkt_size_average         1
# fwd_header_len           1
# Byts_max_interval_2s     1
# Byts_min_interval_2s     1
# Byts_mean_interval_2s    1
# Byts_std_interval_2s     1
# Pkts_max_interval_2s     1
# Pkts_mean_interval_2s    1
# Pkts_min_interval_2s     1
# Pkts_std_interval_2s     2
# active_max               2
# active_mean              2
# active_min               2
# active_std               2
# idle_max                 2
# idle_mean                2
# idle_min                 2
# idle_std                 2
# TnBPDstIP                2
# TnBPSrcIP                2
# TnPPDstIP                2
# TnPPSrcIP                2
# TnPPerDport              2
# Tn_FlowsPDstIP           2
# ...

# %%
d['src_port'].fillna(d['src_port'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/293307303.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['src_port'].fillna(d['src_port'].median(),inplace=True)

# %%
d['src_port'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['dst_port'].fillna(d['dst_port'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/178196058.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['dst_port'].fillna(d['dst_port'].median(),inplace=True)

# %%
d['dst_port'].value_counts()
# Out:
# dst_port
# 443.0      12760
# 53.0        4830
# 80.0        1680
# 445.0       1345
# 139.0       1320
#            ...
# 42626.0        1
# 34870.0        1
# 41781.0        1
# 45454.0        1
# 35710.0        1
# Name: count, Length: 10385, dtype: int64

# %%
d['dst_port'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['flow_duration'].fillna(d['flow_duration'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/4117501463.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['flow_duration'].fillna(d['flow_duration'].median(),inplace=True)

# %%
d['flow_duration'].isnull().sum()
# Out:
# np.int64(0)

# %%
d.head()
# Out:
#    flow_ID  eth_type  ip_proto  src_port  dst_port  flow_duration  \
# 0    14188      2048       6.0     443.0   37004.0          0.385
# 1    29086      2048       6.0   43496.0      80.0          6.747
# 2    28055      2048       6.0    5432.0    1537.0          0.443
# 3    43515      2048       6.0      88.0    3030.0          0.183
# 4     8701      2048       6.0   38224.0     443.0          0.338
#
#    tot_len_pkts  tot_pkts  flow_byts_s  flow_pkts_s  ...  idle_std  \
# 0           0.0       0.0      0.00000     0.000000  ...       0.0
# 1         547.0       2.0     81.07307     0.296428  ...       0.0
# 2           0.0       0.0      0.00000     0.000000  ...       0.0
# 3           0.0       0.0      0.00000     0.000000  ...       0.0
# 4           0.0       0.0      0.00000     0.000000  ...       0.0
#
#      TnBPDstIP  TnBPSrcIP  TnPPDstIP  TnPPSrcIP  TnPPerDport  Tn_FlowsPDstIP  \
# 0  110354785.0      726.0    93144.0       11.0          0.0           179.0
# ...

# %%
d['flow_duration'].isnull().sum()
# Out:
# np.int64(0)

# %%
d.isnull().sum()
# Out:
# flow_ID                  0
# eth_type                 0
# ip_proto                 1
# src_port                 0
# dst_port                 0
# flow_duration            0
# tot_len_pkts             1
# tot_pkts                 1
# flow_byts_s              1
# flow_pkts_s              1
# pkt_size_average         1
# fwd_header_len           1
# Byts_max_interval_2s     1
# Byts_min_interval_2s     1
# Byts_mean_interval_2s    1
# Byts_std_interval_2s     1
# Pkts_max_interval_2s     1
# Pkts_mean_interval_2s    1
# Pkts_min_interval_2s     1
# Pkts_std_interval_2s     2
# active_max               2
# active_mean              2
# active_min               2
# active_std               2
# idle_max                 2
# idle_mean                2
# idle_min                 2
# idle_std                 2
# TnBPDstIP                2
# TnBPSrcIP                2
# TnPPDstIP                2
# TnPPSrcIP                2
# TnPPerDport              2
# Tn_FlowsPDstIP           2
# ...

# %%
d['tot_pkts'].median()
# Out:
# 1.0

# %%
d['tot_len_pkts'].fillna(d['tot_len_pkts'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3595420504.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['tot_len_pkts'].fillna(d['tot_len_pkts'].median(),inplace=True)

# %%
d['tot_len_pkts'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['tot_pkts'].fillna(d['tot_pkts'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/666301824.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['tot_pkts'].fillna(d['tot_pkts'].median(),inplace=True)

# %%
d['tot_pkts'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['flow_byts_s'].fillna(d['flow_byts_s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/2186293361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['flow_byts_s'].fillna(d['flow_byts_s'].median(),inplace=True)

# %%
d['flow_byts_s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['flow_pkts_s'].fillna(d['flow_pkts_s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3816719917.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['flow_pkts_s'].fillna(d['flow_pkts_s'].median(),inplace=True)

# %%
d['flow_pkts_s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Byts_max_interval_2s'].fillna(d['Byts_max_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3006632629.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Byts_max_interval_2s'].fillna(d['Byts_max_interval_2s'].median(),inplace=True)

# %%
d['Byts_max_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Byts_min_interval_2s'].fillna(d['Byts_min_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/4286685733.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Byts_min_interval_2s'].fillna(d['Byts_min_interval_2s'].median(),inplace=True)

# %%
d['Byts_min_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Byts_mean_interval_2s'].fillna(d['Byts_mean_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3633680940.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Byts_mean_interval_2s'].fillna(d['Byts_mean_interval_2s'].median(),inplace=True)

# %%
d['Byts_mean_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Byts_std_interval_2s'].fillna(d['Byts_std_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3877808458.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Byts_std_interval_2s'].fillna(d['Byts_std_interval_2s'].median(),inplace=True)

# %%
d['Byts_std_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Pkts_max_interval_2s'].fillna(d['Pkts_max_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/264070740.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Pkts_max_interval_2s'].fillna(d['Pkts_max_interval_2s'].median(),inplace=True)

# %%
d['Pkts_max_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Pkts_min_interval_2s'].fillna(d['Pkts_min_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/1286988706.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Pkts_min_interval_2s'].fillna(d['Pkts_min_interval_2s'].median(),inplace=True)

# %%
d['Pkts_min_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Pkts_mean_interval_2s'].fillna(d['Pkts_mean_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/2727627611.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Pkts_mean_interval_2s'].fillna(d['Pkts_mean_interval_2s'].median(),inplace=True)

# %%
d['Pkts_mean_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['Pkts_std_interval_2s'].fillna(d['Pkts_std_interval_2s'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3691687667.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Pkts_std_interval_2s'].fillna(d['Pkts_std_interval_2s'].median(),inplace=True)

# %%
d['Pkts_std_interval_2s'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['pkt_size_average'].fillna(d['pkt_size_average'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/2293475368.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['pkt_size_average'].fillna(d['pkt_size_average'].median(),inplace=True)

# %%
d['pkt_size_average'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['fwd_header_len'].isnull().sum()
# Out:
# np.int64(1)

# %%
d['fwd_header_len'].fillna(d['fwd_header_len'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/1316340972.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['fwd_header_len'].fillna(d['fwd_header_len'].median(),inplace=True)

# %%
d['fwd_header_len'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['active_max'].fillna(d['active_max'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/476798417.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['active_max'].fillna(d['active_max'].median(),inplace=True)

# %%
d['active_max'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['active_mean'].fillna(d['active_mean'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/1271949873.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['active_mean'].fillna(d['active_mean'].median(),inplace=True)

# %%
d['active_mean'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['active_min'].fillna(d['active_min'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/1982822974.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['active_min'].fillna(d['active_min'].median(),inplace=True)

# %%
d['active_min'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['active_std'].fillna(d['active_std'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/1219665179.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['active_std'].fillna(d['active_std'].median(),inplace=True)

# %%
d['active_std'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['idle_std'].fillna(d['idle_std'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/1919844647.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['idle_std'].fillna(d['idle_std'].median(),inplace=True)

# %%
d['idle_std'].isnull().sum()
# Out:
# np.int64(0)

# %%
d['idle_min'].fillna(d['idle_min'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/1407437676.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['idle_min'].fillna(d['idle_min'].median(),inplace=True)

# %%
d['idle_mean'].fillna(d['idle_mean'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3194430402.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['idle_mean'].fillna(d['idle_mean'].median(),inplace=True)

# %%
d['idle_max'].fillna(d['idle_max'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/726970001.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['idle_max'].fillna(d['idle_max'].median(),inplace=True)

# %%
d['TnBPDstIP'].fillna(d['TnBPDstIP'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/2836179091.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['TnBPDstIP'].fillna(d['TnBPDstIP'].median(),inplace=True)

# %%
d['TnBPSrcIP'].fillna(d['TnBPSrcIP'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/2770195538.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['TnBPSrcIP'].fillna(d['TnBPSrcIP'].median(),inplace=True)

# %%
d['TnPPDstIP'].fillna(d['TnPPDstIP'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3786267462.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['TnPPDstIP'].fillna(d['TnPPDstIP'].median(),inplace=True)

# %%
d['TnPPSrcIP'].fillna(d['TnPPSrcIP'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/4003638087.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['TnPPSrcIP'].fillna(d['TnPPSrcIP'].median(),inplace=True)

# %%
d['TnPPerDport'].fillna(d['TnPPerDport'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3856550780.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['TnPPerDport'].fillna(d['TnPPerDport'].median(),inplace=True)

# %%
d['Tn_FlowsPDstIP'].fillna(d['Tn_FlowsPDstIP'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3052203981.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Tn_FlowsPDstIP'].fillna(d['Tn_FlowsPDstIP'].median(),inplace=True)

# %%
d.isnull().sum()
# Out:
# flow_ID                  0
# eth_type                 0
# ip_proto                 1
# src_port                 0
# dst_port                 0
# flow_duration            0
# tot_len_pkts             0
# tot_pkts                 0
# flow_byts_s              0
# flow_pkts_s              0
# pkt_size_average         0
# fwd_header_len           0
# Byts_max_interval_2s     0
# Byts_min_interval_2s     0
# Byts_mean_interval_2s    0
# Byts_std_interval_2s     0
# Pkts_max_interval_2s     0
# Pkts_mean_interval_2s    0
# Pkts_min_interval_2s     0
# Pkts_std_interval_2s     0
# active_max               0
# active_mean              0
# active_min               0
# active_std               0
# idle_max                 0
# idle_mean                0
# idle_min                 0
# idle_std                 0
# TnBPDstIP                0
# TnBPSrcIP                0
# TnPPDstIP                0
# TnPPSrcIP                0
# TnPPerDport              0
# Tn_FlowsPDstIP           0
# ...

# %%
d['Tn_FlowsPSrcIP'].fillna(d['Tn_FlowsPSrcIP'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3089895386.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Tn_FlowsPSrcIP'].fillna(d['Tn_FlowsPSrcIP'].median(),inplace=True)

# %%
X=d.drop(columns='Attack',axis=1)
Y=d['Attack']

# %%
X
# Out:
#        flow_ID  eth_type  ip_proto  src_port  dst_port  flow_duration  \
# 0        14188      2048       6.0     443.0   37004.0          0.385
# 1        29086      2048       6.0   43496.0      80.0          6.747
# 2        28055      2048       6.0    5432.0    1537.0          0.443
# 3        43515      2048       6.0      88.0    3030.0          0.183
# 4         8701      2048       6.0   38224.0     443.0          0.338
# ...        ...       ...       ...       ...       ...            ...
# 80850     6266      2048       6.0   35006.0     443.0          0.238
# 80851    17639      2048       6.0      23.0    2897.0          0.587
# 80852    39573      2048       6.0     464.0    1411.0          0.640
# 80853      861      2048       6.0     443.0   49102.0          0.969
# 80854    15796      2048       6.0     443.0   46498.0          0.790
#
#        tot_len_pkts  tot_pkts  flow_byts_s  flow_pkts_s  ...  idle_min  \
# ...

# %%
Y
# Out:
# 0        0.0
# 1        0.0
# 2        1.0
# 3        1.0
# 4        0.0
#         ...
# 80850    0.0
# 80851    1.0
# 80852    1.0
# 80853    0.0
# 80854    0.0
# Name: Attack, Length: 80855, dtype: float64

# %%
Y.isnull().sum()
# Out:
# np.int64(2)

# %%
Y.isnull().sum()
# Out:
# np.int64(2)

# %%
Y.median()
# Out:
# 1.0

# %%
Y.fillna(Y.median(),inplace=True)

# %%
Y
# Out:
# 0        0.0
# 1        0.0
# 2        1.0
# 3        1.0
# 4        0.0
#         ...
# 80850    0.0
# 80851    1.0
# 80852    1.0
# 80853    0.0
# 80854    0.0
# Name: Attack, Length: 80855, dtype: float64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.33241006,  0.        , -0.33396086, ..., -0.71539762,
#          0.13047407, -0.97371456],
#        [-0.40340638,  0.        , -0.33396086, ..., -0.71539762,
#          1.65302142,  0.91150443],
#        [-1.32593737,  0.        , -0.33396086, ..., -0.71539762,
#         -0.39290158, -0.97371456],
#        ...,
#        [ 1.54726579,  0.        , -0.33396086, ..., -0.71539762,
#         -0.1740354 ,  0.91150443],
#        [ 0.91722613,  0.        , -0.33396086, ..., -0.35405476,
#         -0.88772947, -0.97371456],
#        [-0.78314823,  0.        , -0.33396086, ..., -0.68760201,
#          0.84416814, -0.97371456]])

# %%
X_test
# Out:
# array([[-0.61479517,  0.        , -0.33396086, ..., -0.71539762,
#          2.33816773,  0.91150443],
#        [ 0.32457956,  0.        , -0.33396086, ..., -0.71539762,
#         -0.21209909,  0.91150443],
#        [ 1.46296293,  0.        , -0.33396086, ...,  0.1184705 ,
#         -0.88772947,  0.91150443],
#        ...,
#        [ 0.87056901,  0.        , -0.33396086, ..., -0.71539762,
#         -0.74499066,  0.91150443],
#        [-0.28373169,  0.        , -0.33396086, ..., -0.70613241,
#          0.90126366, -0.97371456],
#        [ 0.22806499,  0.        , -0.33396086, ...,  0.98939943,
#         -0.88772947,  0.91150443]])

# %%
Y_train
# Out:
# 29128    0.0
# 51585    1.0
# 9978     0.0
# 69288    1.0
# 30145    1.0
#         ...
# 80232    0.0
# 33867    1.0
# 31019    1.0
# 44566    0.0
# 72173    0.0
# Name: Attack, Length: 64684, dtype: float64

# %%
Y_test
# Out:
# 34340    1.0
# 4740     1.0
# 10606    1.0
# 50096    0.0
# 68493    1.0
#         ...
# 8148     0.0
# 574      1.0
# 36215    1.0
# 44965    0.0
# 26109    1.0
# Name: Attack, Length: 16171, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
xdf=pd.DataFrame(X_test)

# %%
xdf
# Out:
#              0    1         2         3         4         5         6   \
# 0     -0.614795  0.0 -0.333961 -0.713016 -0.578362  0.415154 -0.015866
# 1      0.324580  0.0 -0.333961 -0.363528 -0.590464  0.441440 -0.015866
# 2      1.462963  0.0 -0.333961 -0.589622 -0.356009 -0.192398 -0.015935
# 3      1.268249  0.0 -0.333961  1.208832 -0.652543  0.169002 -0.014671
# 4      1.006751  0.0 -0.333961 -0.640543 -0.573836  0.451082 -0.015866
# ...         ...  ...       ...       ...       ...       ...       ...
# 16166 -1.057280  0.0 -0.333961  1.055211 -0.652543  0.563492 -0.012148
# 16167 -1.686309  0.0 -0.333961 -0.644384  1.668181 -0.223638 -0.015935
# 16168  0.870569  0.0 -0.333961 -0.728107 -0.583222  0.469575 -0.015866
# 16169 -0.283732  0.0 -0.333961  1.738916 -0.669838 -0.226148 -0.015547
# 16170  0.228065  0.0 -0.333961 -0.677683 -0.516139 -0.193851 -0.015935
#
#              7         8         9   ...        26        27        28  \
# ...

# %%
X.isnull().sum()
# Out:
# flow_ID                  0
# eth_type                 0
# ip_proto                 1
# src_port                 0
# dst_port                 0
# flow_duration            0
# tot_len_pkts             0
# tot_pkts                 0
# flow_byts_s              0
# flow_pkts_s              0
# pkt_size_average         0
# fwd_header_len           0
# Byts_max_interval_2s     0
# Byts_min_interval_2s     0
# Byts_mean_interval_2s    0
# Byts_std_interval_2s     0
# Pkts_max_interval_2s     0
# Pkts_mean_interval_2s    0
# Pkts_min_interval_2s     0
# Pkts_std_interval_2s     0
# active_max               0
# active_mean              0
# active_min               0
# active_std               0
# idle_max                 0
# idle_mean                0
# idle_min                 0
# idle_std                 0
# TnBPDstIP                0
# TnBPSrcIP                0
# TnPPDstIP                0
# TnPPSrcIP                0
# TnPPerDport              0
# Tn_FlowsPDstIP           0
# ...

# %%
d['ip_proto'].fillna(d['ip_proto'].median(),inplace=True)
# Out:
# /tmp/ipykernel_6356/3840301701.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['ip_proto'].fillna(d['ip_proto'].median(),inplace=True)

# %%
xdf.fillna(xdf.median(),inplace=True)

# %%
x=pd.DataFrame(xdf)
a=x.to_numpy()

# %%
Y_pred=model.predict(a)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9999381609053244

# %%
Y.value_counts()
# Out:
# Attack
# 1.0    43608
# 0.0    37247
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import xgboost as xgb

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[7487,    1],
#        [   0, 8683]])

# %%
from sklearn.pipeline import Pipeline

from category_encoders import TargetEncoder

# %%
# !pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()

# %%
estimators=[('encoder',TargetEncoder()),('clf',XGBClassifier())]

# %%
pipe=Pipeline(steps=estimators)

# %%
pipe
# Out:
# Pipeline(steps=[('encoder', TargetEncoder()),
#                 ('clf',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
# ...

# %%
# !pip install scikit_optimize
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from skopt import BayesSearchCV

# %%
from skopt.space import Real,Categorical,Integer

# %%
search_space = {
    'max_depth': Integer(3, 8),
    'learning_rate': Real(0.01, 0.3, prior='log-uniform'),
    'n_estimators': Integer(100, 500),
    'subsample': Real(0.6, 1.0),
    'colsample_bytree': Real(0.6, 1.0),
    'reg_alpha': Real(0.0, 5.0),
    'reg_lambda': Real(0.1, 5.0),
    'gamma': Real(0.0, 5.0)
}

# %%
opt=BayesSearchCV(pipe,search_space,n_iter=100,cv=5,scoring='roc_auc',random_state=8)

# %%
from skopt import BayesSearchCV

# %%
opt = BayesSearchCV(
    xgb,
    search_spaces=search_space,
    n_iter=10,
    cv=5
)

# %%
opt.fit(X_train,Y_train)
# Out:
# BayesSearchCV(cv=5,
#               estimator=XGBClassifier(base_score=None, booster=None,
#                                       callbacks=None, colsample_bylevel=None,
#                                       colsample_bynode=None,
#                                       colsample_bytree=None, device=None,
#                                       early_stopping_rounds=None,
#                                       enable_categorical=False,
#                                       eval_metric=None, feature_types=None,
#                                       feature_weights=None, gamma=None,
#                                       grow_policy=None, importance_type=None,
#                                       interaction_constraints=No...
#                              'max_depth': Integer(low=3, high=8, prior='uniform', transform='normalize'),
#                              'n_estimators': Integer(low=100, high=500, prior='uniform', transform='normalize'),
# ...

# %%
opt.best_params_
# Out:
# OrderedDict([('colsample_bytree', 0.883363879917018),
#              ('gamma', 1.948034806965215),
#              ('learning_rate', 0.013363792891261014),
#              ('max_depth', 3),
#              ('n_estimators', 181),
#              ('reg_alpha', 0.15027680856619877),
#              ('reg_lambda', 3.6162175542925397),
#              ('subsample', 0.7515441455841694)])

# %%
opt.best_score_
# Out:
# np.float64(1.0)

# %%
opt.predict(X_test)
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
opt.predict_proba(X_test)
# Out:
# array([[0.04169798, 0.958302  ],
#        [0.04169798, 0.958302  ],
#        [0.04169798, 0.958302  ],
#        ...,
#        [0.04169798, 0.958302  ],
#        [0.9517845 , 0.04821549],
#        [0.04169798, 0.958302  ]], dtype=float32)
